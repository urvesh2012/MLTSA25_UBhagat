# %% [markdown]
# <a href="https://colab.research.google.com/github/urvesh2012/MLTSA25_UBhagat/blob/main/labs/WK_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pylab as plt

# %%
N=100
np.random.seed(17)
y=np.random.randn(N)
plt.hist(y)
# Out:
# (array([ 2.,  0.,  4., 18., 18., 30., 20.,  2.,  3.,  3.]),
#  array([-3.39993078, -2.72542196, -2.05091314, -1.37640433, -0.70189551,
#         -0.02738669,  0.64712213,  1.32163094,  1.99613976,  2.67064858,
#          3.34515739]),
#  <BarContainer object of 10 artists>)

# %%
t = np.linspace(0,N,N)
t.shape,y.shape
# Out:
# ((100,), (100,))

# %%
plt.plot(t,y)
plt.xlabel('t')
plt.ylabel('y')
# Out:
# Text(0, 0.5, 'y')

# %%
plt.hist(y[:50],alpha =0.4)
plt.hist(y[50:],alpha =0.4)
# Out:
# (array([ 2.,  0.,  0.,  4., 11., 10., 12.,  7.,  2.,  2.]),
#  array([-3.39993078, -2.77282501, -2.14571924, -1.51861347, -0.8915077 ,
#         -0.26440193,  0.36270384,  0.98980961,  1.61691538,  2.24402115,
#          2.87112692]),
#  <BarContainer object of 10 artists>)
